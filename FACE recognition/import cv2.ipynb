# %%
import cv2
import matplotlib.pyplot as plt

# %%
img=cv2.imread(".\DSC_0179.jpg")

# %%
plt.imshow(img)

# %%
plt.imshow(img[...,[2,1,0]])
img.shape
# Out:
# (6000, 4000, 3)

# %%
plt.imshow(img.reshape(12000,2000,3))
