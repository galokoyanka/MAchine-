# %%
from sklearn.datasets import make_blobs

# %%
import matplotlib.pyplot as plt

# %%
x,y=make_blobs( n_samples=500,
    n_features=2,
    centers=5,
    random_state=3,)

# %%
x.shape,y.shape
# Out:
# ((500, 2), (500,))

# %%
plt.scatter(x[:,0],x[:,1],c=y)
plt.show()

# %%
#kmeans
plt.scatter(x[:,0],x[:,1])
plt.show()

# %%
k=5
color=["red","black","green","orange","yellow"]

# %%
clusters={}
for i in range(k):
    centre=20*(np.random.random((2,))-0.5)
    clusters[i]={
            'center':centre,
            'points':[],
            'color':color[i]
               }

# %%
import numpy as np

# %% [raw]
# clusters

# %%
def dista(a,b):
    return np.sqrt(np.sum((a-b)**2))


def assignToClusters(clusters,x):
    m=x.shape[0]
    for ix in range(m):
        dist=[]
        for i in range(k):
            d=dista(x[ix],clusters[i]['center'])
            dist.append(d)
        cluster_idx=np.argmin(dist)
        clusters[cluster_idx]['points'].append(x[ix])
def updateclusterecenter(clusters):
    for kx in range(k):
        pts=np.array(clusters[kx]['points'])
        
        if pts.shape[0]>0:
            new_coordinate=np.mean(pts,axis=0)
            clusters[kx]['center']=new_coordinate
            clusters[kx]['points']=[]

# %%
def plotclusters(clusters):
    #plt.scatter(x[:,0],x[:,1])
    for i in range(k):
        pts=np.array(clusters[i]['points'])
        if pts.shape[0]>0:
            plt.scatter(pts[:,0],pts[:,1],color=clusters[i]['color'])
        plt.scatter(clusters[i]['center'][0],clusters[i]['center'][1],marker='^')
    plt.show()

# %%
plotclusters(clusters)

# %%
assignToClusters(clusters,x)
plotclusters(clusters)
updateclusterecenter(clusters)

# %%
from sklearn.cluster import KMeans

# %%
kmeans=KMeans?

# %%
kmeans=KMeans(n_clusters=5)

# %%
kmeans.fit(x)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=5, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
centers=kmeans.cluster_centers_

# %%
plt.scatter(x[:,0],x[:,1])
plt.scatter(centers[:,0],centers[:,1])
plt.show()
