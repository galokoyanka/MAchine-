# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Linear_X_Train.csv")
dy=pd.read_csv("Linear_Y_Train.csv")
dt=pd.read_csv("Linear_X_Test.csv")

# %%
X=df.values
Y=dy.values
T=dt.values

# %%
print(type(X))
# Out:
# <class 'numpy.ndarray'>

# %%
def total_error(x,y,theta):
    error=0
    m=x.shape[0]
    for i in range(m):
        yi=theta[0]+theta[1]*x[i]
        e=yi-y[i]
        error+=e**2
    return e

# %%
def gradient_descent(x,y,learning_rate=0.0001,step=1000):
    theta=np.zeros((2,))
    for i in range(step):
        grad=gradient(x,y,theta)
        theta[0]=theta[0]-learning_rate*grad[0]
        theta[1]=theta[1]-learning_rate*grad[1]
        print(theta)
    return theta

# %%
def gradient(x,y,theta):
    grade=np.zeros((2,))
    m=x.shape[0]
    for i in range(1):
        yi=theta[0]+theta[1]*x[i]
        grade[0]+=(yi-y[i])*2
        grade[1]+=x[i]*(yi-y[i])*2
        print(grade)
    return grade

# %%
theta=gradient_descent(X,Y)
# Out:
# [ 0.18220223 -0.05271246]
# [-1.82202234e-05  5.27124578e-06]
# [ 0.18216274 -0.05270103]
# [-3.64364978e-05  1.05413491e-05]
# [ 0.18212326 -0.05268961]
# [-5.46488240e-05  1.58103101e-05]
# [ 0.18208379 -0.05267819]
# [-7.28572029e-05  2.10781292e-05]
# [ 0.18204432 -0.05266677]
# [-9.10616352e-05  2.63448065e-05]
# [ 0.18200487 -0.05265536]
# [-1.09262122e-04  3.16103423e-05]
# [ 0.18196542 -0.05264395]
# [-1.27458664e-04  3.68747368e-05]
# [ 0.18192598 -0.05263254]
# [-1.45651262e-04  4.21379904e-05]
# [ 0.18188655 -0.05262113]
# [-1.63839917e-04  4.74001032e-05]
# [ 0.18184713 -0.05260972]
# [-1.82024630e-04  5.26610755e-05]
# [ 0.18180771 -0.05259832]
# [-2.00205401e-04  5.79209075e-05]
# [ 0.18176831 -0.05258692]
# [-2.18382232e-04  6.31795995e-05]
# [ 0.18172891 -0.05257552]
# [-2.36555124e-04  6.84371518e-05]
# [ 0.18168953 -0.05256413]
# [-2.54724076e-04  7.36935645e-05]
# [ 0.18165015 -0.05255273]
# [-2.72889091e-04  7.89488380e-05]
# [ 0.18161078 -0.05254134]
# ...

# %%
print(theta)
# Out:
# [-0.01638254  0.00473959]
